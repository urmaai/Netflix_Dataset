# %% [markdown]
# <h2><b>Netflix Dataset</b></h2>
#
# Набор данных Netflix Titles представляет собой исчерпывающую подборку фильмов и телешоу, доступных на Netflix, охватывающую различные аспекты, такие как тип названия, режиссер, актерский состав, страна производства, год выпуска, рейтинг, продолжительность, жанры (указаны в) и краткое описание. Этот набор данных имеет важное значение для анализа тенденций в контенте Netflix, понимания популярности жанров и изучения распределения контента по различным регионам и периодам времени.

# %%
import pandas as pd

# %%
data=pd.read_csv(r"C:\Users\user\Desktop\python projects\Netflix_2.csv")

# %%
data.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %%
data.tail()
# Out:
#      Show_Id Category                                    Title     Director  \
# 7784   s7783    Movie                                     Zozo  Josef Fares
# 7785   s7784    Movie                                   Zubaan  Mozez Singh
# 7786   s7785    Movie                        Zulu Man in Japan          NaN
# 7787   s7786  TV Show                    Zumbo's Just Desserts          NaN
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS     Sam Dunn
#
#                                                    Cast  \
# 7784  Imad Creidi, Antoinette Turk, Elias Gergi, Car...
# 7785  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...
# 7786                                            Nasty C
# 7787                         Adriano Zumbo, Rachel Khoo
# 7788                                                NaN
#
#                                                 Country        Release_Date  \
# 7784  Sweden, Czech Republic, United Kingdom, Denmar...    October 19, 2020
# ...

# %%
data.shape
# Out:
# (7789, 11)

# %%
data.size
# Out:
# 85679

# %%
data.columns
# Out:
# Index(['Show_Id', 'Category', 'Title', 'Director', 'Cast', 'Country',
#        'Release_Date', 'Rating', 'Duration', 'Type', 'Description'],
#       dtype='str')

# %%
data.dtypes
# Out:
# Show_Id         str
# Category        str
# Title           str
# Director        str
# Cast            str
# Country         str
# Release_Date    str
# Rating          str
# Duration        str
# Type            str
# Description     str
# dtype: object

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 7789 entries, 0 to 7788
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Show_Id       7789 non-null   str
#  1   Category      7789 non-null   str
#  2   Title         7789 non-null   str
#  3   Director      5401 non-null   str
#  4   Cast          7071 non-null   str
#  5   Country       7282 non-null   str
#  6   Release_Date  7779 non-null   str
#  7   Rating        7782 non-null   str
#  8   Duration      7789 non-null   str
#  9   Type          7789 non-null   str
#  10  Description   7789 non-null   str
# dtypes: str(11)
# memory usage: 669.5 KB

# %% [markdown]
# <h3>Задание 1. Есть ли в этом наборе данных повторяющиеся записи? Если да, то удалите повторяющиеся записи.</h3>

# %%
data[data.duplicated()]
# Out:
#      Show_Id Category              Title        Director  \
# 6300    s684    Movie           Backfire     Dave Patten
# 6622   s6621    Movie  The Lost Okoroshi  Abba T. Makama
#
#                                                    Cast        Country  \
# 6300  Black Deniro, Byron "Squally" Vinson, Dominic ...  United States
# 6622  Seun Ajayi, Judith Audu, Tope Tedela, Ifu Enna...        Nigeria
#
#            Release_Date Rating Duration  \
# 6300      April 5, 2019  TV-MA   97 min
# 6622  September 4, 2020  TV-MA   94 min
#
#                                        Type  \
# 6300  Dramas, Independent Movies, Thrillers
# 6622   Comedies, Dramas, Independent Movies
#
#                                             Description
# 6300  When two would-be robbers accidentally kill a ...
# 6622  A disillusioned security guard transforms into...

# %%
data.drop_duplicates(inplace=True)

# %%
data[data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Show_Id, Category, Title, Director, Cast, Country, Release_Date, Rating, Duration, Type, Description]
# Index: []

# %%
data.shape
# Out:
# (7787, 11)

# %% [markdown]
# <h3>Задание 2. Присутствуют ли в каком-либо столбце нулевые значения? Покажите с помощью heatmap</h3>

# %%
data.isnull().sum()
# Out:
# Show_Id            0
# Category           0
# Title              0
# Director        2388
# Cast             718
# Country          507
# Release_Date      10
# Rating             7
# Duration           0
# Type               0
# Description        0
# dtype: int64

# %%
import seaborn as sns

# %%
sns.heatmap(data.isnull())
# Out:
# <Axes: >

# %% [markdown]
# <h3> 1) Какой id у сериала House of cards и кто его режиссёр? </h3>

# %%
data[data['Title'].isin(['House of Cards'])]
# Out:
#      Show_Id Category           Title  \
# 2832   s2833  TV Show  House of Cards
#
#                                                Director  \
# 2832  Robin Wright, David Fincher, Gerald McRaney, J...
#
#                                                    Cast        Country  \
# 2832  Kevin Spacey, Robin Wright, Kate Mara, Corey S...  United States
#
#           Release_Date Rating   Duration                     Type  \
# 2832  November 2, 2018  TV-MA  6 Seasons  TV Dramas, TV Thrillers
#
#                                             Description
# 2832  A ruthless politician will stop at nothing to ...

# %%
data[data['Title'].str.contains('House of Cards')]
# Out:
#      Show_Id Category           Title  \
# 2832   s2833  TV Show  House of Cards
#
#                                                Director  \
# 2832  Robin Wright, David Fincher, Gerald McRaney, J...
#
#                                                    Cast        Country  \
# 2832  Kevin Spacey, Robin Wright, Kate Mara, Corey S...  United States
#
#           Release_Date Rating   Duration                     Type  \
# 2832  November 2, 2018  TV-MA  6 Seasons  TV Dramas, TV Thrillers
#
#                                             Description
# 2832  A ruthless politician will stop at nothing to ...

# %% [markdown]
# <h3>2) В каком году было выпущено наибольшее количество телешоу и фильмов? Покажите Bar graph

# %%
data['Release_Date'] = data['Release_Date'].str.strip()  # Убираем лишние пробелы

# %%
 #Преобразуем в datetime 
data['Data_new'] = pd.to_datetime(data['Release_Date'], errors='coerce', dayfirst=False)

# %%
data.dtypes
# Out:
# Show_Id                    str
# Category                   str
# Title                      str
# Director                   str
# Cast                       str
# Country                    str
# Release_Date               str
# Rating                     str
# Duration                   str
# Type                       str
# Description                str
# Data_new        datetime64[us]
# dtype: object

# %%
data['Data_new'].dt.year.value_counts()
# Out:
# Data_new
# 2019.0    2153
# 2020.0    2009
# 2018.0    1685
# 2017.0    1225
# 2016.0     443
# 2021.0     117
# 2015.0      88
# 2014.0      25
# 2011.0      13
# 2013.0      11
# 2012.0       3
# 2008.0       2
# 2009.0       2
# 2010.0       1
# Name: count, dtype: int64

# %%
data['Data_new'].dt.year.value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Data_new'>

# %% [markdown]
# <h3>3) Сколько фильмов и телешоу содержится в наборе данных? Покажите с помощью Bar graph

# %%
data.groupby('Category').Category.count()
# Out:
# Category
# Movie      5377
# TV Show    2410
# Name: Category, dtype: int64

# %%
sns.countplot(x='Category', data=data)
# Out:
# <Axes: xlabel='Category', ylabel='count'>

# %% [markdown]
# <h3> 4) Покажите все фильмы, вышедшие в 2020 году

# %%
data['Year']=data['Data_new'].dt.year

# %%
data[(data['Category']=='Movie') & (data['Year']==2020)]
# Out:
#      Show_Id Category                                    Title  \
# 4         s5    Movie                                       21
# 6         s7    Movie                                      122
# 14       s15    Movie                                     3022
# 27       s28    Movie                                   #Alive
# 28       s29    Movie            #AnneFrank - Parallel Stories
# ...      ...      ...                                      ...
# 7762   s7761    Movie                                Zaki Chan
# 7783   s7782    Movie                                     Zoom
# 7784   s7783    Movie                                     Zozo
# 7786   s7785    Movie                        Zulu Man in Japan
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                          Director  \
# 4                  Robert Luketic
# 6                 Yasir Al Yasiri
# 14                     John Suits
# 27                         Cho Il
# ...

# %% [markdown]
# <h3> 5) Отобразить только названия всех телешоу, выпущенных только в Италии.

# %%
data[(data['Category'] == 'TV Show') & 
     (data['Country']=='Italy')]['Title']
# Out:
# 111                              44 Cats
# 668                                 Baby
# 760                              Bat Pat
# 1179                     Call Me Francis
# 1554                               Curon
# 3817                           Luna Nera
# 3851    Maggie & Bianca: Fashion Friends
# 5379           SanPa: Sins of the Savior
# 5868              Suburra: Blood on Rome
# 5881                          Summertime
# 6941                           The Trial
# 7641                           Winx Club
# Name: Title, dtype: str

# %% [markdown]
# <h3> 6) Покажите 10 режиссеров, которые предоставили Netflix наибольшее количество телешоу и фильмов?

# %%
data['Director'].value_counts().head(10)
# Out:
# Director
# Raúl Campos, Jan Suter    18
# Marcus Raboy              16
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Youssef Chahine           12
# Martin Scorsese           12
# Jay Chapman               12
# Steven Spielberg          10
# David Dhawan               9
# Kunle Afolayan             8
# Name: count, dtype: int64

# %% [markdown]
# <h3> 7) Показать все записи, где категория — фильм, тип — комедии или страна — Великобритания

# %%
data[(data['Category']=='Movie') & (data['Type']=='Comedies')]
# Out:
#      Show_Id Category                        Title                Director  \
# 33       s34    Movie                 #realityhigh        Fernando Lebrija
# 72       s73    Movie                     17 Again             Burr Steers
# 84       s85    Movie                    21 & Over  Jon Lucas, Scott Moore
# 148     s149    Movie         A Bad Moms Christmas  Jon Lucas, Scott Moore
# 174     s175    Movie  A Futile and Stupid Gesture              David Wain
# ...      ...      ...                          ...                     ...
# 7341   s7340    Movie         Undercover Brother 2            Leslie Small
# 7590   s7589    Movie            Where's the Money         Scott Zabielski
# 7623   s7622    Movie                    Wild Oats            Andy Tennant
# 7634   s7633    Movie                 Wine Country             Amy Poehler
# 7664   s7663    Movie                      Work It           Laura Terruso
#
#                                                    Cast  \
# ...

# %%
data[(data['Category']=='Movie') & (data['Type']=='Comedies') | (data['Country']=='United Kingdom')]
# Out:
#      Show_Id Category                   Title          Director  \
# 19       s20    Movie                     '89               NaN
# 33       s34    Movie            #realityhigh  Fernando Lebrija
# 58       s59  TV Show             100% Hotter               NaN
# 72       s73    Movie                17 Again       Burr Steers
# 82       s83    Movie     2036 Origin Unknown     Hasraf Dulull
# ...      ...      ...                     ...               ...
# 7670   s7669  TV Show  World War II in Colour               NaN
# 7671   s7670  TV Show  World's Busiest Cities               NaN
# 7688   s7687    Movie  XV: Beyond the Tryline  Pierre Deschamps
# 7725   s7724    Movie            You Can Tutu       James Brown
# 7740   s7739  TV Show         Young Wallander               NaN
#
#                                                    Cast         Country  \
# 19                   Lee Dixon, Ian Wright, Paul Merson  United Kingdom
# ...

# %% [markdown]
# <h3> 8) В скольких фильмах/сериалах снимался Том Круз?

# %%
data_n=data.dropna()

# %%
data[data['Cast'].str.contains('Tom Cruise')]
# Out:
#      Show_Id Category     Title              Director  \
# 3860   s3861    Movie  Magnolia  Paul Thomas Anderson
# 5071   s5071    Movie  Rain Man        Barry Levinson
#
#                                                    Cast        Country  \
# 3860  Jeremy Blackman, Tom Cruise, Melinda Dillon, A...  United States
# 5071  Dustin Hoffman, Tom Cruise, Valeria Golino, Ge...  United States
#
#          Release_Date Rating Duration                        Type  \
# 3860  January 1, 2020      R  189 min  Dramas, Independent Movies
# 5071     July 1, 2019      R  134 min      Classic Movies, Dramas
#
#                                             Description   Data_new    Year
# 3860  Through chance, human action, past history and... 2020-01-01  2020.0
# 5071  A fast-talking yuppie is forced to slow down w... 2019-07-01  2019.0

# %% [markdown]
# <h3> 9) Какие существуют различные рейтинги, установленные Netflix?

# %%
data['Rating'].unique()
# Out:
# <StringArray>
# [   'TV-MA',        'R',    'PG-13',    'TV-14',    'TV-PG',       'NR',
#      'TV-G',     'TV-Y',        nan,    'TV-Y7',       'PG',        'G',
#     'NC-17', 'TV-Y7-FV',       'UR']
# Length: 15, dtype: str

# %% [markdown]
# <h3> 9.1) Сколько фильмов получили рейтинг TV-14 в Канаде?

# %%
data[(data['Category']=='Movie') & (data['Rating']=='TV-14') & (data['Country']=='Canada')].shape
# Out:
# (11, 13)

# %% [markdown]
# <h3> 9.2) Сколько телешоу получили рейтинг «R» после 2018 года?

# %%
data[(data['Category']=='TV Show') & (data['Rating']=='R') & (data['Year']<2018)].shape
# Out:
# (1, 13)

# %% [markdown]
# <h3> 10) Какова максимальная продолжительность фильма/сериала на Netflix?

# %%
data[['Minutes','Unit']]=data['Duration'].str.split(' ', expand=True)

# %%
data.Minutes.max()
# Out:
# '99'

# %%
data.Minutes.min()
# Out:
# '1'

# %% [markdown]
# <h3> 11) В какой стране самое большое количество телешоу?

# %%
d_tvshow=data[data['Category']=='TV Show']

# %%
d_tvshow.Country.value_counts().head(1)
# Out:
# Country
# United States    705
# Name: count, dtype: int64

# %% [markdown]
# <h3> 12) Как можно отсортировать набор данных по году?

# %%
data.sort_values(by='Year', ascending=False).head()
# Out:
#      Show_Id Category                                           Title  \
# 7147   s7146    Movie                     Tony Parker: The Final Shot
# 980     s981  TV Show                                    Bling Empire
# 4813   s4814    Movie                                     Peepli Live
# 6699   s6698    Movie  The Naked Gun: From the Files of Police Squad!
# 3441   s3442  TV Show                      Korean Pork Belly Rhapsody
#
#                             Director  \
# 7147                   Florent Bodin
# 980                              NaN
# 4813  Anusha Rizvi, Mahmood Farooqui
# 6699                    David Zucker
# 3441                             NaN
#
#                                                    Cast        Country  \
# 7147                                        Tony Parker         France
# 980                                                 NaN            NaN
# 4813  Omkar Das Manikpuri, Raghuvir Yadav, Malaika S...          India
# ...
